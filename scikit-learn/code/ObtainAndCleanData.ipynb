# %%
import pandas as pd

# %%
url_pm25 = "https://www.arpae.it/estraistaz.asp?q=111&i=01.01.2010&f=04.01.2014&s=7000014&p=BO"
url_pm10 = "https://www.arpae.it/estraistaz.asp?q=5&i=01.01.2010&f=01.01.2014&s=7000002&p=BO"
url_no2  = "https://www.arpae.it/estraistaz.asp?q=8&i=02.01.2019&f=04.01.2021&s=7000014&p=BO"

# %%
data = pd.read_html(url_pm25)

# %%
dati = data[0]
dati
# Out:
#                  Stazione Data inizio   Data fine    Strumento  PM2.5  \
# 0     GIARDINI MARGHERITA  31/12/2009  01/01/2010  FAI SWAM 5A   26.0
# 1     GIARDINI MARGHERITA  01/01/2010  02/01/2010  FAI SWAM 5A   33.0
# 2     GIARDINI MARGHERITA  02/01/2010  03/01/2010  FAI SWAM 5A    9.0
# 3     GIARDINI MARGHERITA  03/01/2010  04/01/2010  FAI SWAM 5A    5.0
# 4     GIARDINI MARGHERITA  04/01/2010  05/01/2010  FAI SWAM 5A   25.0
# ...                   ...         ...         ...          ...    ...
# 1460  GIARDINI MARGHERITA  30/12/2013  31/12/2013  FAI SWAM 5A   20.0
# 1461  GIARDINI MARGHERITA  31/12/2013  01/01/2014  FAI SWAM 5A   17.0
# 1462  GIARDINI MARGHERITA  01/01/2014  02/01/2014  FAI SWAM 5A   27.0
# 1463  GIARDINI MARGHERITA  02/01/2014  03/01/2014  FAI SWAM 5A   56.0
# 1464  GIARDINI MARGHERITA  03/01/2014  04/01/2014  FAI SWAM 5A   39.0
#
#      Unità di misura  F1  F2  F3  F4
# 0              ug/m3 NaN   1   1   1
# 1              ug/m3 NaN   1   1   1
# ...

# %%
dati.to_csv('PM25_2010-2014.csv')

# %%
for index, row in dati.iterrows(): 
    print(index, row['Data fine'], row['PM2.5'])
# Out:
# 0 01/01/2010 26.0
# 1 02/01/2010 33.0
# 2 03/01/2010 9.0
# 3 04/01/2010 5.0
# 4 05/01/2010 25.0
# 5 06/01/2010 29.0
# 6 07/01/2010 nan
# 7 08/01/2010 53.0
# 8 09/01/2010 nan
# 9 10/01/2010 nan
# 10 11/01/2010 14.0
# 11 12/01/2010 21.0
# 12 13/01/2010 37.0
# 13 14/01/2010 61.0
# 14 15/01/2010 50.0
# 15 16/01/2010 52.0
# 16 17/01/2010 36.0
# 17 18/01/2010 48.0
# 18 19/01/2010 47.0
# 19 20/01/2010 39.0
# 20 21/01/2010 34.0
# 21 22/01/2010 39.0
# 22 23/01/2010 43.0
# 23 24/01/2010 49.0
# 24 25/01/2010 51.0
# 25 26/01/2010 56.0
# 26 27/01/2010 48.0
# 27 28/01/2010 32.0
# 28 29/01/2010 13.0
# 29 30/01/2010 42.0
# 30 31/01/2010 85.0
# 31 01/02/2010 22.0
# 32 02/02/2010 20.0
# 33 03/02/2010 11.0
# 34 04/02/2010 17.0
# 35 05/02/2010 68.0
# 36 06/02/2010 83.0
# 37 07/02/2010 8.0
# 38 08/02/2010 nan
# 39 09/02/2010 21.0
# 40 10/02/2010 42.0
# 41 11/02/2010 30.0
# 42 12/02/2010 14.0
# 43 13/02/2010 26.0
# 44 14/02/2010 22.0
# 45 15/02/2010 44.0
# 46 16/02/2010 68.0
# 47 17/02/2010 69.0
# ...
